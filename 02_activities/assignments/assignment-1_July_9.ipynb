# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy 
import PIL
import requests

x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

# define our figure and axes (just one this time)
fig, ax = plt.subplots(figsize=(7, 3))

# now call both bar and plot elements to the same axes (ax)
ax.bar(x, y1,
color = "indigo")
ax.plot(x, y2,
color = "red")

# %%
y2_sd = np.std(y2)
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

ax.errorbar(x, y2,
        yerr = y2_sd,
        fmt = "none")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2,
        color = "red")
ax.errorbar(x,
        y2,
        yerr = y2_sd,
        fmt = "none",
        ecolor= "indigo",
        elinewidth= 4,
        capsize = 6,
        capthick= 4 )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2,
        color = "red")
ax.errorbar(x,
        y2,
        yerr = y2_sd,
        fmt = "none",
        ecolor = "indigo",
        elinewidth = 4,
        capsize = 6,
        capthick = 4,
        errorevery= 2 )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
from PIL import Image # to open images
import requests # to get images from URLs
from io import BytesIO # to store images

response = requests.get('https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png')
image_file = BytesIO(response.content)
image = Image.open(image_file)

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

ax_image = fig.add_axes([0.1, # x coordinate (ON FIGURE, NOT AXES)
                        0.11, # y coordinate (ON FIGURE, NOT AXES)
                        0.15, # image width
                        0.35] # image height)
                        )

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2,
        color = "red")
ax_image = fig.add_axes([0.1, 0.11, 0.15, 0.35])
ax_image.imshow(image)
ax_image.axis('off')
# Out:
# (-0.5, 219.5, 425.5, -0.5)

# %%
# Activity 1:
# Lack of numbers, lot's of text, blury text won't be easy for perception 

#Activity 2:
# Describing the environment: laboratory or sth similar
# Mentioning amount of people: 2
# Describing each person and what they are doing
# Consider the context

# Activity 3:
"""Level 1:
The chart represents the daily routines of famous creative people. It shows different types of activities the famous people did during the day. 
Sleep is covered in mint colour, creative work is coloured in red, day job/admin activity is coloured in green, food/leisure activity is coloured 
in yellow, exercise is coloured in navy blue and other activity is coloured in grey.
Level 2:
The chart shows that some of famous people were mostly working on their creative projects and had less sleep, when others had to balance between 
rest, daily job and creative work.
Level 3:
Some of the represented famous people were staying late while snacking and working on their creative work, when others had a stable daily 
routine and early sleep. The chart overall shows that most of the represented people had enough of sleep and enough of time to have food, 
so they could leave the rest for creative work and other type of work. Trend shows that they didn’t spend much time on exercises or other activities.
Level 4:
None of the represented figures had a day job and lots of free time, which shows that it might have been hard to become a creative person for a woman 
at that time.""" 

# Activity 4:
#Moral: the whole diagram itself
